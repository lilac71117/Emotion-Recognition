# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, precision_recall_fscore_support
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
import warnings
import os
import random
from PIL import Image
from pathlib import Path
import copy
import pickle
import sys
import timm
warnings.filterwarnings('ignore')


class FocalLoss(nn.Module):
    def __init__(self, gamma=1.5, alpha=None, reduction='mean'):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss

        if self.alpha is not None:
            alpha_t = self.alpha[targets]
            focal_loss = alpha_t * focal_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        return focal_loss.sum()


class ViTEmotion(nn.Module):
    def __init__(self, num_classes=7, pretrained=True):
        super().__init__()
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        self.backbone = timm.create_model(
            'vit_small_patch16_224',
            pretrained=pretrained,
            num_classes=num_classes,
            drop_path_rate=0.1
        )

        self.to(self.device)

    def forward(self, x):
        x = x.to(self.device)
        return self.backbone(x)


class TrainTransform:
    def __init__(self):
        self.transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(degrees=15),
            transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)),
            transforms.RandAugment(magnitude=7, num_ops=2),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
        ])

    def __call__(self, image):
        return self.transform(image)


class ValTestTransform:
    def __init__(self):
        self.transform = transforms.Compose([
            transforms.Resize(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
        ])

    def __call__(self, image):
        return self.transform(image)


class BaseRAFDBDataset(Dataset):
    def __init__(self, root_dir, split='train'):
        self.root_dir = Path(root_dir) / split
        self.images = []
        self.labels = []
        self._load_data()

    def _load_data(self):
        for class_folder in sorted(self.root_dir.iterdir()):
            if not class_folder.is_dir():
                continue
            try:
                class_idx = int(class_folder.name)
                if class_idx not in range(1, 8):
                    continue
                label = class_idx - 1
                for img_path in class_folder.glob('*.[jp][pn]g'):
                    self.images.append(str(img_path))
                    self.labels.append(label)
            except:
                continue

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]
        image = Image.open(img_path).convert('RGB')
        return image, label


class TransformedDataset(Dataset):
    def __init__(self, base_dataset, transform):
        self.base_dataset = base_dataset
        self.transform = transform

    def __len__(self):
        return len(self.base_dataset)

    def __getitem__(self, idx):
        image, label = self.base_dataset[idx]
        image = self.transform(image)
        return image, torch.tensor(label, dtype=torch.long)


def load_fixed_split(root_dir, splits_path="dataset_splits.pkl"):
    with open(splits_path, 'rb') as f:
        splits = pickle.load(f)

    base_train = BaseRAFDBDataset(root_dir, 'train')
    base_test = BaseRAFDBDataset(root_dir, 'test')

    train_indices = splits['train_indices']
    val_indices = splits['val_indices']

    train_ds = TransformedDataset(
        torch.utils.data.Subset(base_train, train_indices),
        TrainTransform()
    )

    val_ds = TransformedDataset(
        torch.utils.data.Subset(base_train, val_indices),
        ValTestTransform()
    )

    test_ds = TransformedDataset(base_test, ValTestTransform())

    emotion_labels = {
        0: 'Surprise', 1: 'Fear', 2: 'Disgust',
        3: 'Happiness', 4: 'Sadness', 5: 'Anger', 6: 'Neutral'
    }

    return train_ds, val_ds, test_ds, emotion_labels


def create_dataloaders(batch_size=64, root_dir=None, splits_path=None):
    train_ds, val_ds, test_ds, emotion_labels = load_fixed_split(root_dir, splits_path)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0)

    return train_loader, val_loader, test_loader, emotion_labels


def train_model(model, train_loader, val_loader, criterion, optimizer,
                scheduler, num_epochs=40, device='cpu',
                patience=10, min_delta=0.001,
                checkpoint_dir="checkpoints"):

    # Создаём папку для чекпоинтов
    checkpoint_dir = Path(checkpoint_dir)
    checkpoint_dir.mkdir(parents=True, exist_ok=True)

    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    best_val_acc = -float('inf')
    best_model_state = None
    epochs_no_improve = 0

    print(f"Early stopping: patience={patience}, min_delta={min_delta}")
    print(f"Чекпоинты будут сохраняться в папку: {checkpoint_dir.resolve()}\n")

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        train_pbar = tqdm(train_loader, desc=f'Epoch {epoch+1:02d}/{num_epochs} [Train]')
        for inputs, labels in train_pbar:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

            train_pbar.set_postfix({'Loss': f'{loss.item():.4f}',
                                  'Acc': f'{100.*correct/total:.2f}%'})

        train_loss = running_loss / len(train_loader)
        train_acc = 100. * correct / total
        train_losses.append(train_loss)
        train_accs.append(train_acc)

        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            val_pbar = tqdm(val_loader, desc=f'Epoch {epoch+1:02d}/{num_epochs} [Val]')
            for inputs, labels in val_pbar:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()
                val_pbar.set_postfix({'Loss': f'{loss.item():.4f}',
                                    'Acc': f'{100.*correct/total:.2f}%'})

        val_loss = val_loss / len(val_loader)
        val_acc = 100. * correct / total
        val_losses.append(val_loss)
        val_accs.append(val_acc)

        if scheduler is not None:
            scheduler.step(val_loss)


        current_epoch = epoch + 1


        checkpoint_path = checkpoint_dir / f"epoch_{current_epoch:02d}.pth"
        torch.save({
            'epoch': current_epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict() if scheduler else None,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'train_acc': train_acc,
            'val_acc': val_acc,
        }, checkpoint_path)

        print(f"Чекпоинт сохранён: {checkpoint_path.name}")

        is_best = False
        if val_acc > best_val_acc + min_delta:
            best_val_acc = val_acc
            best_model_state = copy.deepcopy(model.state_dict())
            is_best = True
            epochs_no_improve = 0

            best_path = checkpoint_dir / "best_model.pth"
            torch.save({
                'epoch': current_epoch,
                'model_state_dict': best_model_state,
                'val_acc': best_val_acc,
                'train_acc': train_acc,
            }, best_path)
            print(f"НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: {val_acc:.2f}% (сохранена как best_model.pth)")
        else:
            epochs_no_improve += 1
            print(f"Нет улучшения ({epochs_no_improve}/{patience})")

        print(f'Epoch {current_epoch:02d}: '
              f'Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | '
              f'Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%\n')

        if epochs_no_improve >= patience:
            print(f"\nEarly stopping сработал на эпохе {current_epoch}")
            print(f"Лучшая валидационная точность: {best_val_acc:.2f}%")
            break

    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\nЗагружена лучшая модель (Val Acc = {best_val_acc:.2f}%)")

    return {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accs': train_accs,
        'val_accs': val_accs,
        'best_val_acc': best_val_acc,
        'stopped_epoch': current_epoch
    }


def test_model(model, test_loader, criterion, device, emotion_labels):
    model.eval()
    all_preds = []
    all_labels = []
    test_loss = 0.0

    with torch.no_grad():
        for inputs, labels in tqdm(test_loader, desc='Тестирование'):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    test_loss /= len(test_loader)
    test_acc = accuracy_score(all_labels, all_preds) * 100

    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average=None, zero_division=0)
    _, _, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro', zero_division=0)

    print(f"\nTest Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.2f}%")
    print(f"Macro F1-Score: {f1_macro:.4f}")

    print("\nPer-class metrics:")
    for i, lbl in emotion_labels.items():
        print(f" {lbl}: F1={f1[i]:.3f}, Prec={precision[i]:.3f}, Rec={recall[i]:.3f}")

    return all_preds, all_labels, test_loss, test_acc


def plot_confusion_matrix(y_true, y_pred, emotion_labels):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=list(emotion_labels.values()),
                yticklabels=list(emotion_labels.values()))
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()

def plot_training_history(history):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(history['train_losses'], label='Train Loss')
    axes[0].plot(history['val_losses'], label='Val Loss')
    axes[0].set_title('Loss')
    axes[0].legend()
    axes[0].grid(True)

    axes[1].plot(history['train_accs'], label='Train Acc')
    axes[1].plot(history['val_accs'], label='Val Acc')
    axes[1].set_title('Accuracy')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()


def train_model(model, train_loader, val_loader, criterion, optimizer,
                scheduler, num_epochs=40, device='cpu',
                patience=10, min_delta=0.001,
                checkpoint_dir="checkpoints"):

    checkpoint_dir = Path(checkpoint_dir)
    checkpoint_dir.mkdir(parents=True, exist_ok=True)

    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    best_val_acc = -float('inf')
    best_model_state = None
    epochs_no_improve = 0

    print(f"Early stopping: patience={patience}, min_delta={min_delta}")
    print(f"Чекпоинты будут сохраняться в папку: {checkpoint_dir.resolve()}\n")

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        train_pbar = tqdm(train_loader, desc=f'Epoch {epoch+1:02d}/{num_epochs} [Train]')
        for inputs, labels in train_pbar:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

            train_pbar.set_postfix({'Loss': f'{loss.item():.4f}',
                                  'Acc': f'{100.*correct/total:.2f}%'})

        train_loss = running_loss / len(train_loader)
        train_acc = 100. * correct / total
        train_losses.append(train_loss)
        train_accs.append(train_acc)

        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            val_pbar = tqdm(val_loader, desc=f'Epoch {epoch+1:02d}/{num_epochs} [Val]')
            for inputs, labels in val_pbar:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()
                val_pbar.set_postfix({'Loss': f'{loss.item():.4f}',
                                    'Acc': f'{100.*correct/total:.2f}%'})

        val_loss = val_loss / len(val_loader)
        val_acc = 100. * correct / total
        val_losses.append(val_loss)
        val_accs.append(val_acc)

        if scheduler is not None:
            scheduler.step(val_loss)

        current_epoch = epoch + 1

        checkpoint_path = checkpoint_dir / f"epoch_{current_epoch:02d}.pth"
        torch.save({
            'epoch': current_epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict() if scheduler else None,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'train_acc': train_acc,
            'val_acc': val_acc,
        }, checkpoint_path)

        print(f"Чекпоинт сохранён: {checkpoint_path.name}")

        is_best = False
        if val_acc > best_val_acc + min_delta:
            best_val_acc = val_acc
            best_model_state = copy.deepcopy(model.state_dict())
            is_best = True
            epochs_no_improve = 0

            best_path = checkpoint_dir / "best_model.pth"
            torch.save({
                'epoch': current_epoch,
                'model_state_dict': best_model_state,
                'val_acc': best_val_acc,
                'train_acc': train_acc,
            }, best_path)
            print(f"НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: {val_acc:.2f}% (сохранена как best_model.pth)")
        else:
            epochs_no_improve += 1
            print(f"Нет улучшения ({epochs_no_improve}/{patience})")

        print(f'Epoch {current_epoch:02d}: '
              f'Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | '
              f'Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%\n')

        if epochs_no_improve >= patience:
            print(f"\nEarly stopping сработал на эпохе {current_epoch}")
            print(f"Лучшая валидационная точность: {best_val_acc:.2f}%")
            break

    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\nЗагружена лучшая модель (Val Acc = {best_val_acc:.2f}%)")

    return {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accs': train_accs,
        'val_accs': val_accs,
        'best_val_acc': best_val_acc,
        'stopped_epoch': current_epoch
    }


def main():
    print("РАСПОЗНАВАНИЕ ЭМОЦИЙ НА RAF-DB")
    print("ViT-Small/16")

    RAFDB_ROOT = r"DATASET"
    SPLITS_PATH = r"dataset_splits.pkl"

    BATCH_SIZE = 64
    LEARNING_RATE = 0.0002
    NUM_EPOCHS = 40
    RANDOM_SEED = 42
    CHECKPOINT_DIR = "checkpoints"

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Устройство: {device}")


    torch.manual_seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    random.seed(RANDOM_SEED)

    print("\n1. Загрузка данных с фиксированным разбиением")
    train_loader, val_loader, test_loader, emotion_labels = create_dataloaders(
        batch_size=BATCH_SIZE,
        root_dir=RAFDB_ROOT,
        splits_path=SPLITS_PATH
    )

    print(f" Train: {len(train_loader.dataset):6d} изображений")
    print(f" Val:   {len(val_loader.dataset):6d} изображений")
    print(f" Test:  {len(test_loader.dataset):6d} изображений")

    print("\n2. Создание модели ViT-Small/16")
    model = ViTEmotion(num_classes=7, pretrained=True)
    print(f"Всего параметров: {sum(p.numel() for p in model.parameters()):,}")


    criterion = FocalLoss(gamma=1.5, alpha=None)
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=5e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=5, min_lr=1e-6
    )

    print("\n3. Обучение")
    history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        num_epochs=NUM_EPOCHS,
        device=device,
        patience=10,
        min_delta=0.001,
        checkpoint_dir=CHECKPOINT_DIR
    )

    print("\n5. Визуализация кривых обучения")
    plot_training_history(history)

    print("\n6. Тестирование лучшей модели")
    all_preds, all_labels, test_loss, test_acc = test_model(
        model=model,
        test_loader=test_loader,
        criterion=criterion,
        device=device,
        emotion_labels=emotion_labels
    )

    plot_confusion_matrix(all_labels, all_preds, emotion_labels)

    print("\n7. Финальное сохранение моделей")

    final_path = Path(CHECKPOINT_DIR) / "final_model.pth"
    torch.save({
        'model_state_dict': model.state_dict(),
        'history': history,
        'test_acc': test_acc,
        'test_loss': test_loss,
    }, final_path)

    print(f"Финальная модель сохранена: {final_path}")
    print(f"Лучшая модель: {Path(CHECKPOINT_DIR) / 'best_model.pth'}")
    print(f"Все чекпоинты эпох: {CHECKPOINT_DIR}/epoch_XX.pth")

    print("\n")
    print(f"ИТОГОВАЯ ТОЧНОСТЬ НА ТЕСТЕ: {test_acc:.2f}%")


if __name__ == "__main__":
    main()
# Out:
# РАСПОЗНАВАНИЕ ЭМОЦИЙ НА RAF-DB
# ViT-Small/16
# Устройство: cuda
#
# 1. Загрузка данных
#  Train:  10430 изображений
#  Val:     1841 изображений
#  Test:    3068 изображений
#
# 2. Создание модели ViT-Small/16
# Всего параметров: 21,668,359
#
# 3. Обучение
# Early stopping: patience=10, min_delta=0.001
# Чекпоинты будут сохраняться в папку: /content/checkpoints
# Epoch 01/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 01/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_01.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 66.81% (сохранена как best_model.pth)
# Epoch 01: Train Loss: 0.8922 | Train Acc: 54.01% | Val Loss: 0.6064 | Val Acc: 66.81%
# Epoch 02/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 02/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_02.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 71.37% (сохранена как best_model.pth)
# Epoch 02: Train Loss: 0.5483 | Train Acc: 70.11% | Val Loss: 0.5265 | Val Acc: 71.37%
# Epoch 03/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 03/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_03.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 74.96% (сохранена как best_model.pth)
# Epoch 03: Train Loss: 0.4586 | Train Acc: 73.99% | Val Loss: 0.4472 | Val Acc: 74.96%
# Epoch 04/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 04/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_04.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 77.68% (сохранена как best_model.pth)
# Epoch 04: Train Loss: 0.3989 | Train Acc: 76.68% | Val Loss: 0.4022 | Val Acc: 77.68%
# Epoch 05/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 05/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_05.pth
# Нет улучшения (1/10)
# Epoch 05: Train Loss: 0.3674 | Train Acc: 78.32% | Val Loss: 0.4090 | Val Acc: 76.32%
# Epoch 06/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 06/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_06.pth
# Нет улучшения (2/10)
# Epoch 06: Train Loss: 0.3317 | Train Acc: 80.22% | Val Loss: 0.3854 | Val Acc: 77.57%
# Epoch 07/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 07/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_07.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 78.16% (сохранена как best_model.pth)
# Epoch 07: Train Loss: 0.3119 | Train Acc: 80.58% | Val Loss: 0.3886 | Val Acc: 78.16%
# Epoch 08/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 08/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_08.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 79.03% (сохранена как best_model.pth)
# Epoch 08: Train Loss: 0.2848 | Train Acc: 82.40% | Val Loss: 0.3693 | Val Acc: 79.03%
# Epoch 09/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 09/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_09.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 80.61% (сохранена как best_model.pth)
# Epoch 09: Train Loss: 0.2654 | Train Acc: 83.39% | Val Loss: 0.3418 | Val Acc: 80.61%
# Epoch 10/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 10/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_10.pth
# Нет улучшения (1/10)
# Epoch 10: Train Loss: 0.2425 | Train Acc: 84.31% | Val Loss: 0.4048 | Val Acc: 78.71%
# Epoch 11/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 11/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_11.pth
# Нет улучшения (2/10)
# Epoch 11: Train Loss: 0.2285 | Train Acc: 85.38% | Val Loss: 0.3681 | Val Acc: 80.07%
# Epoch 12/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 12/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_12.pth
# Нет улучшения (3/10)
# Epoch 12: Train Loss: 0.2071 | Train Acc: 86.04% | Val Loss: 0.3673 | Val Acc: 79.36%
# Epoch 13/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 13/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_13.pth
# Нет улучшения (4/10)
# Epoch 13: Train Loss: 0.2022 | Train Acc: 86.32% | Val Loss: 0.3877 | Val Acc: 79.47%
# Epoch 14/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 14/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_14.pth
# Нет улучшения (5/10)
# Epoch 14: Train Loss: 0.1912 | Train Acc: 87.11% | Val Loss: 0.3971 | Val Acc: 79.47%
# Epoch 15/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 15/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_15.pth
# Нет улучшения (6/10)
# Epoch 15: Train Loss: 0.1822 | Train Acc: 87.13% | Val Loss: 0.3788 | Val Acc: 78.22%
# Epoch 16/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 16/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_16.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 83.27% (сохранена как best_model.pth)
# Epoch 16: Train Loss: 0.1178 | Train Acc: 91.32% | Val Loss: 0.3684 | Val Acc: 83.27%
# Epoch 17/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 17/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_17.pth
# Нет улучшения (1/10)
# Epoch 17: Train Loss: 0.0978 | Train Acc: 92.92% | Val Loss: 0.4246 | Val Acc: 79.47%
# Epoch 18/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 18/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_18.pth
# Нет улучшения (2/10)
# Epoch 18: Train Loss: 0.0864 | Train Acc: 93.33% | Val Loss: 0.3648 | Val Acc: 82.56%
# Epoch 19/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 19/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_19.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 83.54% (сохранена как best_model.pth)
# Epoch 19: Train Loss: 0.0812 | Train Acc: 93.78% | Val Loss: 0.3610 | Val Acc: 83.54%
# Epoch 20/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 20/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_20.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 84.08% (сохранена как best_model.pth)
# Epoch 20: Train Loss: 0.0792 | Train Acc: 93.99% | Val Loss: 0.3721 | Val Acc: 84.08%
# Epoch 21/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 21/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_21.pth
# Нет улучшения (1/10)
# Epoch 21: Train Loss: 0.0759 | Train Acc: 94.27% | Val Loss: 0.4011 | Val Acc: 81.91%
# Epoch 22/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 22/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_22.pth
# Нет улучшения (2/10)
# Epoch 22: Train Loss: 0.0556 | Train Acc: 95.99% | Val Loss: 0.3966 | Val Acc: 83.92%
# Epoch 23/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 23/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_23.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 84.14% (сохранена как best_model.pth)
# Epoch 23: Train Loss: 0.0467 | Train Acc: 96.59% | Val Loss: 0.4086 | Val Acc: 84.14%
# Epoch 24/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 24/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_24.pth
# Нет улучшения (1/10)
# Epoch 24: Train Loss: 0.0446 | Train Acc: 96.52% | Val Loss: 0.3939 | Val Acc: 83.49%
# Epoch 25/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 25/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_25.pth
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: Val Acc: 84.41% (сохранена как best_model.pth)
# Epoch 25: Train Loss: 0.0390 | Train Acc: 96.99% | Val Loss: 0.4065 | Val Acc: 84.41%
# Epoch 26/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 26/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_26.pth
# Нет улучшения (1/10)
# Epoch 26: Train Loss: 0.0441 | Train Acc: 96.82% | Val Loss: 0.3941 | Val Acc: 84.36%
# Epoch 27/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 27/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_27.pth
# Нет улучшения (2/10)
# Epoch 27: Train Loss: 0.0337 | Train Acc: 97.21% | Val Loss: 0.4503 | Val Acc: 83.70%
# Epoch 28/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 28/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_28.pth
# Нет улучшения (3/10)
# Epoch 28: Train Loss: 0.0328 | Train Acc: 97.48% | Val Loss: 0.4304 | Val Acc: 83.60%
# Epoch 29/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 29/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_29.pth
# Нет улучшения (4/10)
# Epoch 29: Train Loss: 0.0257 | Train Acc: 97.83% | Val Loss: 0.4253 | Val Acc: 84.41%
# Epoch 30/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 30/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_30.pth
# Нет улучшения (5/10)
# Epoch 30: Train Loss: 0.0304 | Train Acc: 97.70% | Val Loss: 0.4329 | Val Acc: 84.25%
# Epoch 31/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 31/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_31.pth
# Нет улучшения (6/10)
# Epoch 31: Train Loss: 0.0276 | Train Acc: 97.89% | Val Loss: 0.4423 | Val Acc: 83.22%
# Epoch 32/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 32/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_32.pth
# Нет улучшения (7/10)
# Epoch 32: Train Loss: 0.0276 | Train Acc: 98.04% | Val Loss: 0.4476 | Val Acc: 84.41%
# Epoch 33/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 33/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_33.pth
# Нет улучшения (8/10)
# Epoch 33: Train Loss: 0.0253 | Train Acc: 98.12% | Val Loss: 0.4641 | Val Acc: 83.60%
# Epoch 34/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 34/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_34.pth
# Нет улучшения (9/10)
# Epoch 34: Train Loss: 0.0237 | Train Acc: 98.18% | Val Loss: 0.4285 | Val Acc: 84.03%
# Epoch 35/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 35/40 [Val]:   0%|          | 0/29 [00:00<?, ?it/s]
# Чекпоинт сохранён: epoch_35.pth
# Нет улучшения (10/10)
# Epoch 35: Train Loss: 0.0208 | Train Acc: 98.49% | Val Loss: 0.4290 | Val Acc: 83.87%
#
#
# Early stopping сработал на эпохе 35
# Лучшая валидационная точность: 84.41%
#
# Загружена лучшая модель (Val Acc = 84.41%)
#
# 5. Визуализация кривых обучения
# 6. Тестирование лучшей модели
# Тестирование:   0%|          | 0/48 [00:00<?, ?it/s]
# Test Loss: 0.3574
# Test Accuracy: 86.25%
# Macro F1-Score: 0.7901
#
# Per-class metrics:
#  Surprise: F1=0.866, Prec=0.850, Rec=0.881
#  Fear: F1=0.600, Prec=0.696, Rec=0.527
#  Disgust: F1=0.622, Prec=0.638, Rec=0.606
#  Happiness: F1=0.939, Prec=0.952, Rec=0.927
#  Sadness: F1=0.835, Prec=0.839, Rec=0.831
#  Anger: F1=0.833, Prec=0.888, Rec=0.784
#  Neutral: F1=0.836, Prec=0.798, Rec=0.878
# 7. Финальное сохранение моделей
# Финальная модель сохранена: checkpoints/final_model.pth
# Лучшая модель: checkpoints/best_model.pth
# Все чекпоинты эпох: checkpoints/epoch_XX.pth
#
# ИТОГОВАЯ ТОЧНОСТЬ НА ТЕСТЕ: 86.25%
